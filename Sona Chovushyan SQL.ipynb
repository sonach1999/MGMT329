# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect("tips.db")
cur= conn.cursor()
query = "SELECT name FROM sqlite_master WHERE type='table'"
cur.execute(query)
cur.fetchall()
query = "SELECT * FROM Observation LIMIT 5;"
pd.read_sql(query, conn)
# Out:
#    total_bill   tip  size  sex_id  smoker_id  day_id  time_id
# 0       16.99  1.01     2       1          1       3        1
# 1       10.34  1.66     3       0          1       3        1
# 2       21.01  3.50     3       0          1       3        1
# 3       23.68  3.31     2       0          1       3        1
# 4       24.59  3.61     4       1          1       3        1

# %%
query = "SELECT * FROM Observation WHERE total_bill > 50;"
pd.read_sql(query, conn)
# Out:
#    total_bill   tip  size  sex_id  smoker_id  day_id  time_id
# 0       50.81  10.0     3       0          0       2        1

# %%
query = "SELECT AVG(tip) FROM Observation;"
pd.read_sql(query, conn)
# Out:
#    AVG(tip)
# 0  2.998279

# %%
query = "SELECT MAX(total_bill) FROM Observation;"
pd.read_sql(query, conn)
# Out:
#    MAX(total_bill)
# 0            50.81

# %% [markdown]
# # **<font color='red'> Question 4 is missing. Minus 4 points </font>**

# %%
query = "SELECT size, AVG(total_bill) FROM Observation GROUP BY size;"
pd.read_sql(query, conn)
# Out:
#    size  AVG(total_bill)
# 0     1         7.242500
# 1     2        16.448013
# 2     3        23.277632
# 3     4        28.613514
# 4     5        30.068000
# 5     6        34.830000

# %%
query = "SELECT smoker_id, SUM(tip) FROM Observation GROUP BY smoker_id;"
pd.read_sql(query, conn)
# Out:
#    smoker_id  SUM(tip)
# 0          0    279.81
# 1          1    451.77

# %% [markdown]
# # **<font color='red'> Instead of smoker_id in the query result the actual smoker type should be printed. Minus 1 point </font>**

# %%
query = "SELECT day_id, AVG(tip/total_bill) * 100 AS avg_tip_percentage FROM Observation GROUP BY day_id;"
pd.read_sql(query, conn)
# Out:
#    day_id  avg_tip_percentage
# 0       0           16.127563
# 1       1           16.991303
# 2       2           15.315172
# 3       3           16.689729

# %% [markdown]
# # **<font color='red'> Instead of day_id in the query result the actual day name should be printed. Minus 1 point </font>**

# %%
query = "SELECT total_bill, day_id, time_id FROM Observation;"
pd.read_sql(query, conn)
# Out:
#      total_bill  day_id  time_id
# 0         16.99       3        1
# 1         10.34       3        1
# 2         21.01       3        1
# 3         23.68       3        1
# 4         24.59       3        1
# ..          ...     ...      ...
# 239       29.03       2        1
# 240       27.18       2        1
# 241       22.67       2        1
# 242       17.82       2        1
# 243       18.78       0        1
#
# [244 rows x 3 columns]

# %%
query = "SELECT sex_id, COUNT(*) FROM Observation GROUP BY sex_id;"
pd.read_sql(query, conn)
# Out:
#    sex_id  COUNT(*)
# 0       0       157
# 1       1        87

# %% [markdown]
# # **<font color='red'> Instead of sex_id in the query result the actual sex category should be printed. Minus 1 point </font>**

# %%
query = "SELECT tip FROM Observation WHERE day_id = 6 AND time_id = 2;"
pd.read_sql(query, conn)
# Out:
# Empty DataFrame
# Columns: [tip]
# Index: []

# %% [markdown]
# # **<font color='red'> Incorrect solution. Minus 4 points </font>**

# %%
query = "SELECT sex_id, MAX(total_bill) FROM Observation GROUP BY sex_id;"
pd.read_sql(query, conn)
# Out:
#    sex_id  MAX(total_bill)
# 0       0            50.81
# 1       1            44.30

# %% [markdown]
# # **<font color='red'> Instead of sex_id in the query result the actual sex category should be printed. Minus 1 point </font>**

# %%
query = "SELECT AVG(tip) FROM Observation WHERE size > 4;"
pd.read_sql(query, conn)
# Out:
#    AVG(tip)
# 0      4.56

# %%
query = "SELECT * FROM Observation WHERE day_id IN (5, 6) AND time_id IN (1, 2);"
pd.read_sql(query, conn)
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, size, sex_id, smoker_id, day_id, time_id]
# Index: []

# %%
query = "SELECT * FROM Observation WHERE (tip/total_bill) * 100 > 20;"
pd.read_sql(query, conn)
# Out:
#     total_bill   tip  size  sex_id  smoker_id  day_id  time_id
# 0         8.77  2.00     2       0          1       3        1
# 1        14.78  3.23     2       0          1       3        1
# 2        14.83  3.02     2       1          1       3        1
# 3        16.29  3.71     3       0          1       3        1
# 4        16.97  3.50     3       1          1       3        1
# 5        17.92  4.08     2       0          1       2        1
# 6        13.94  3.06     2       0          1       3        1
# 7        22.23  5.00     2       0          1       3        1
# 8        10.29  2.60     2       1          1       3        1
# 9        18.29  3.76     4       0          0       2        1
# 10        3.07  1.00     1       1          0       2        1
# 11       16.66  3.40     2       0          1       0        0
# 12       18.28  4.00     2       0          1       0        0
# 13       24.71  5.85     2       0          1       0        0
# ...

# %%
##Bonus question

query = "SELECT * FROM Observation WHERE total_bill > 50;"
pd.read_sql(query, conn)

query = "SELECT AVG(tip) FROM Observation;"
pd.read_sql(query, conn)

query = "SELECT MAX(total_bill) FROM Observation;"
pd.read_sql(query, conn)
query = "SELECT size, AVG(total_bill) FROM Observation GROUP BY size;"
pd.read_sql(query, conn)

query = """
SELECT * FROM Observation
WHERE tip = (
    SELECT MAX(tip) FROM Observation
    WHERE tip < (SELECT MAX(tip) FROM Observation)
);
"""
pd.read_sql(query, conn)
# Out:
#    total_bill  tip  size  sex_id  smoker_id  day_id  time_id
# 0       48.33  9.0     4       0          1       2        1
